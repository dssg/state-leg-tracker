# %% [markdown]
# ### This notebook can be removed

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yaml

# %%
from src.utils.general import get_db_conn, get_boto3_session, load_model_s3, load_matrix_s3
from src.utils import project_constants as constants

from triage.component.catwalk.storage import ProjectStorage
# from src.bill_passage.model_analysis_functions import fetch_evaluations_models, fetch_all_evaluations_for_model

# %%
cred_file = '../conf/local/credentials.yaml'
db_conn=get_db_conn(cred_file)
s3_session = get_boto3_session(cred_file)

# experiment_hash = '6c185dd4b5d63791b315c5412b6144a9'
project_path = 's3://aclu-leg-tracker/experiment_data/bill_passage/triage/national_long_term_master_final'

# %%
# experiment_hash=exps['experiment_hash'].at[2]
# q = """
#     with models as (
#         select 
#             model_id, model_hash, model_group_id, model_type, hyperparameters, to_char(train_end_time, 'YYYY-MM-DD') as train_end_time,  train_matrix_uuid
#         from triage_metadata.experiment_models join triage_metadata.models using(model_hash)
#         where experiment_hash='{}'
#         order by train_end_time
#     )
#     select 
#         model_id, model_hash, model_group_id, model_type, hyperparameters, train_end_time,  train_matrix_uuid, matrix_uuid as test_matrix_uuid
#     from models join test_results.prediction_metadata using(model_id)
    
# """.format(experiment_hash)

# models = pd.read_sql(q, db_conn)
# models

# %% [markdown]
# #### Crosstabs config

# %%
config_file = '../src/bill_passage/postmodeling/crosstabs_config.yaml'
with open(config_file) as f:
    config = yaml.safe_load(f)
config
# Out:
# {'output': {'schema': 'test_results', 'table': 'crosstabs'},
#  'thresholds': {'rank_abs': [100],
#   'rank_pct': [10],
#   'score_bins': {'will_not_pass': [0, 0.1],
#    'unlikely': [0.1, 0.35],
#    'coin-toss': [0.35, 0.55],
#    'likely': [0.55, 0.7],
#    'very_likely': [0.7, 0.9],
#    'will_pass': [0.9, 1.0]}},
#  'model_ids': [16465, 16592, 16722, 16850],
#  'project_path': 's3://aclu-leg-tracker/experiment_data/bill_passage/triage/national_lt'}

# %%
model_groups = [654, 694]

# %%
q = """
    select 
        model_id,
        model_group_id,
        train_end_time,
        train_matrix_uuid,
        matrix_uuid as test_matrix_uuid
    from triage_metadata.models join test_results.prediction_metadata using(model_id) 
    where model_group_id={}
    order by train_end_time
""".format(model_groups[0])

models = pd.read_sql(q, db_conn)

# %%
models
# Out:
#     model_id  model_group_id train_end_time                 train_matrix_uuid  \
# 0      13306             654     2012-03-01  ed41532c0975eb6e88e33b4d0edc2cb2
# 1      13431             654     2012-06-01  14070df447e71adba24af3c905690a80
# 2      13559             654     2012-09-01  0c51add8921f06d592f11a56143f1ff7
# 3      13686             654     2012-12-01  9a00c432b68234bd4c21d312bd5799c5
# 4      13814             654     2013-03-01  5187b697a1d350813bddbe9b9380bf85
# 5      13943             654     2013-06-01  c22e470b363d6c502e54e5b5f17d741d
# 6      14068             654     2013-09-01  e423e4032b628c5df32b827fb384e5ca
# 7      14195             654     2013-12-01  09c727d983bd605030aeb622391c7294
# 8      14319             654     2014-03-01  a35b4a125f10f7a003bb3ab1daf0ff30
# 9      14481             654     2014-06-01  3fe3ad88e7713acce45bb1fef68fcc6a
# 10     14609             654     2014-09-01  46225e3ff85d5f7ec50b22131bcdf712
# 11     14737             654     2014-12-01  07a8179c84740b1a23f858b90c9d5a66
# 12     14865             654     2015-03-01  e5a72f84c2ded15791a474b87dda8edd
# 13     14994             654     2015-06-01  ef57e074af6652e954f447b923172efc
# 14     15122             654     2015-09-01  36d532e247395117ea6291dd35b1e38e
# 15     15249             654     2015-12-01  f5cc95c4ca69f6aefbd7a72b6e84c8ed
# 16     15378             654     2016-03-01  5bc24d3160d4869fa1a6223cd618b0da
# 17     15505             654     2016-06-01  724082eac3907209116ab05d20461074
# 18     15633             654     2016-09-01  17147f020a7c729c1ab91c6da3cfbcad
# 19     15761             654     2016-12-01  c3a10ffd58621c3fa8dda7777e1ec436
# 20     15889             654     2017-03-01  78d24fd9059b59f16a5aadbeb798bece
# 21     16018             654     2017-06-01  56911721bfc4b179fd80bc255be43d24
# 22     16145             654     2017-09-01  1d82b77f7a1a566ee64fbaf8a592b4c8
# 23     16274             654     2017-12-01  345acd09ee55605920efd51fe5a87a0d
# 24     16402             654     2018-03-01  605fbb27143a1c95cd05ee3b7b692e8c
# 25     16530             654     2018-06-01  58b86211941e8c84768240f8af923b60
# 26     16658             654     2018-09-01  7b0f5578e0bcdc7eea1384b1abe99396
# 27     16785             654     2018-12-01  1771114359f3a09bbcf9a21d42762898
#
#                     test_matrix_uuid
# 0   e8961f63762d1d19a98cc5af96f6bb2f
# 1   a23d80684324cd5f7d4984827b73ebf5
# 2   ae87b55da4b15dc340fd5159d140743d
# 3   ea4c420bbed3aa1febaaa4e87860703d
# 4   d0e02745bba6773eb09127c29b8b66cc
# 5   f9328b5aaf0d10293cc99a552b33381d
# 6   9e64ae940b3ca0203d08d4c29d2b24df
# 7   c57804081e6de23a7377f6ea09d45fda
# 8   3b9ad1e42ff6eaedec68799430ff827b
# 9   8b1de75fe4181dadca2be02e6af3d899
# 10  2bc85dff17bd82abbff6c750d05ef9ad
# 11  d0f8ee21e604c28b3c57205755d7dca0
# 12  9eb7ceb92d08b3981b2aa2fd9cde278d
# 13  0eb95e8c83417ab67175f8a3e129525d
# 14  5cb580c26136e45b31ba15b6cf058ab2
# 15  888d636c7843525c6ea41b2e754caed9
# 16  71e4dd090775cf3684ebb6795406b9bf
# 17  27d271ee822d0cf98a40c1b73d08a2e3
# 18  db9289017db8c8bfd3f83fa477eea459
# 19  03dea7cd6a204bcf67f319e39694bf2c
# 20  0772581296df7449786df199785895f8
# 21  83439d3bbc239143cbc7dec8438fac0f
# 22  1491b6bda194a2f55562b409f273a541
# 23  aaaa1612b20ab9899424dac8b3a2f1a9
# 24  4ae7556b60a8af3827baf2d94a61320a
# 25  ef18dae69b1d4163c0e412c3e8f8be14
# 26  918dfbddbaff359fdb5a1e2704579d41
# 27  e1c95d86707dc7d6c40ac78ee96b95c4

# %% [markdown]
# ### Analysing a single model

# %%
idx = 12
model_id = models.at[idx, 'model_id']
train_end_time = models.at[idx, 'train_end_time']
# model_id = config['model_ids'][1]

# model_id = 16402

q = """
    select 
        *
    from triage_metadata.models
    where model_id = {}
""".format(model_id)

model_info = pd.read_sql(q, db_conn)
train_end_time = model_info.at[0, 'train_end_time']

# %%
q = """
    select 
        model_id,
        metric,
        parameter,
        split_part("parameter", '_', 1)::int as param_threshold,
        num_labeled_above_threshold,
        stochastic_value as value
    from test_results.evaluations
    where metric!='roc_auc'
    and model_id={}
""".format(model_id)

model_evaluations = pd.read_sql(q, db_conn)
# model_evaluations

# %% [markdown]
# **PR-Curve**

# %%
msk1 = model_evaluations['parameter'].str.contains('pct')
msk_prec = model_evaluations['metric'].str.contains('precision')
msk_recall = model_evaluations['metric'].str.contains('recall')

fig, ax = plt.subplots(figsize=(7,4))
sns.lineplot(data=model_evaluations[msk1 & msk_prec].sort_values('param_threshold'), x='param_threshold', y='value')
sns.lineplot(data=model_evaluations[msk1 & msk_recall].sort_values('param_threshold'), x='param_threshold', y='value')
sns.despine()
ax.set_title('PR-Curve for Model ID: {}, train_end_time {}'.format(model_id, train_end_time))
# Out:
# Text(0.5, 1.0, 'PR-Curve for Model ID: 14865, train_end_time 2015-03-01 00:00:00')

# %% [markdown]
# **Absolute List sizes**

# %%
msk1 = model_evaluations['parameter'].str.contains('abs')
msk_prec = model_evaluations['metric'].str.contains('precision')
msk_recall = model_evaluations['metric'].str.contains('recall')

# %%
# sns.lineplot(data=model_evaluations[msk1 & msk_prec].sort_values('param_threshold'), x='param_threshold', y='value')
# sns.lineplot(data=model_evaluations[msk1 & msk_recall].sort_values('param_threshold'), x='param_threshold', y='value')

# %% [markdown]
# **Predictions -- Score Distribution**

# %%
q = """
    select 
        entity_id, as_of_date, score, label_value, rank_abs_no_ties, rank_abs_with_ties, rank_pct_no_ties, rank_pct_with_ties
    from test_results.predictions where model_id={}
    order by score desc
""".format(model_id)

model_predictions = pd.read_sql(q, db_conn)
model_predictions.head()
# Out:
#    entity_id as_of_date    score  label_value  rank_abs_no_ties  \
# 0     707549 2015-03-01  0.97102            1                 1
# 1     671439 2015-03-08  0.97069            1                 2
# 2     683567 2015-03-29  0.96585            1                 3
# 3     678848 2015-03-29  0.96473            1                 4
# 4     687853 2015-03-15  0.96472            1                 5
#
#    rank_abs_with_ties  rank_pct_no_ties  rank_pct_with_ties
# 0                   1           0.00000             0.00001
# 1                   2           0.00001             0.00001
# 2                   3           0.00001             0.00002
# 3                   4           0.00001             0.00002
# 4                   5           0.00001             0.00003

# %%
fig, ax = plt.subplots(figsize=(7,4))
sns.distplot(model_predictions['score'], kde=False)
ax.set_title('score distribution for Model ID: {}, train_end_time {}'.format(model_id, train_end_time))
sns.despine()

# %% [markdown]
# #### Analysing Features (Model level)

# %%
q = """ select feature, feature_importance, rank_abs, rank_pct from train_results.feature_importances where model_id={} order by rank_abs """.format(model_id)

feature_importance = pd.read_sql(q, db_conn)

# %%
fig, ax = plt.subplots(figsize=(10,7))
n_features_to_plot = 20
sns.barplot(data=feature_importance.iloc[:n_features_to_plot], x='feature_importance', y='feature', color='royalblue')
ax.set_title('Top 20 features for Model ID: {}, train_end_time {}'.format(model_id, train_end_time))
sns.despine()

# %%
feature_importance.head(20)
# Out:
#                                              feature  feature_importance  \
# 0             evnt_cts_entity_id_1month_action_count            0.088806
# 1                evnt_cts_entity_id_all_action_count            0.075293
# 2        rec_evnts_entity_id_all_days_since_evnt_min            0.049915
# 3          sp_success_entity_id_all_success_rate_avg            0.047562
# 4              evnt_cts_entity_id_2week_action_count            0.043299
# 5      evnt_cts_entity_id_all_DISTINCT chamber_count            0.042613
# 6               evnt_cts_entity_id_all_important_sum            0.040904
# 7    evnt_cts_entity_id_2week_DISTINCT chamber_count            0.031219
# 8          sp_success_entity_id_all_success_rate_max            0.030173
# 9             evnt_cts_entity_id_1week_important_imp            0.027065
# 10   rec_evnts_entity_id_all_days_since_imp_evnt_min            0.025235
# 11                   chmbr_entity_id_all_uc_size_max            0.020559
# 12                   chmbr_entity_id_all_lc_size_max            0.019969
# 13  evnt_cts_entity_id_1month_DISTINCT chamber_count            0.019806
# 14              chmbr_entity_id_all_lc_dems_frac_max            0.019055
# 15           evnt_cts_entity_id_1month_important_sum            0.017340
# 16             sess_entity_id_all_remaining_time_min            0.016514
# 17  sp_success_entity_id_all_num_bills_sponsored_max            0.015772
# 18  sp_success_entity_id_all_num_bills_sponsored_avg            0.015053
# 19              chmbr_entity_id_all_uc_dems_frac_max            0.014791
#
#     rank_abs  rank_pct
# 0          1  0.006757
# 1          2  0.013514
# 2          3  0.020270
# 3          4  0.027027
# 4          5  0.033784
# 5          6  0.040541
# 6          7  0.047297
# 7          8  0.054054
# 8          9  0.060811
# 9         10  0.067568
# 10        11  0.074324
# 11        12  0.081081
# 12        13  0.087838
# 13        14  0.094595
# 14        15  0.101351
# 15        16  0.108108
# 16        17  0.114865
# 17        18  0.121622
# 18        19  0.128378
# 19        20  0.135135

# %% [markdown]
# **Relevant Feature inspection**

# %%
outcome_col='lt_passed'

# %%
matrix_storage_engine = ProjectStorage(config['project_path']).matrix_storage_engine() 
matrix_store = matrix_storage_engine.get_store(matrix_uuid=models.at[idx, 'test_matrix_uuid'])
test_matrix = matrix_store.matrix_label_tuple[0]
labels = matrix_store.matrix_label_tuple[1]

test_matrix = test_matrix.merge(labels, on=['entity_id', 'as_of_date'])

# mat_uuid = models.at[idx, 'test_matrix_uuid']
# mat_path = '{}/matrices/{}.csv.gz'.format(project_path, mat_uuid)

# test_matrix = load_matrix_s3(s3_session, mat_path, compression='gzip').reset_index()

# %%
## Joining with predictions
test_matrix = test_matrix.merge(model_predictions, on=['entity_id', 'as_of_date'])

# %% [markdown]
# **Score Buckets**

# %%
buckets = {
    'will_not_pass': [0, 0.10],
    'unlikely': [0.10, 0.35],
    'could go either way': [0.35, 0.55],
    'likely': [0.55, 0.70],
    'very_likely': [0.70, 0.90],
    'will_pass': [0.90, 1.1]
}

def assign_bucket(row, buckets):
    for bucket, lims in buckets.items():
        if row['score'] >= lims[0] and row['score'] < lims[1]:
            row['likelihood_bin'] = bucket
            break
    return row

test_matrix['likelihood_bin'] = None
for bucket_label, limits in buckets.items():
    msk = (test_matrix['score'] >= limits[0]) & (test_matrix['score'] < limits[1]) 
    test_matrix['likelihood_bin'][msk] = bucket_label

#     test_matrix = test_matrix.apply(assign_bucket, buckets=buckets, axis=1)
# Out:
# /home/kasun/.pyenv/versions/aclu/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
label_msk = test_matrix[outcome_col]==1

# %%
feature_name = 'evnt_cts_entity_id_1month_action_count'
# display_name = 'total number of actions/events on the bill'

# %%
# # fig, ax = plt.subplots(figsize=(6,4))
# g = sns.FacetGrid(test_matrix, col=outcome_col, height=4, aspect=1.2)
# g.map(sns.distplot, feature_name, kde=False)
# # plt.title('Distribution of {} w.r.t the label'.format(feature_name))

# %%
bin_subsets = {
    'extremes': ['will_not_pass', 'will_pass'],
    'second_level': ['unlikely', 'very_likely'],
    'mid': ['unlikely', 'could go either way', 'likely'],
    'all': ['unlikely', 'likely' , 'could go either way', 'very_likely', 'will_pass']
}

bin_color_map = {
    'will_not_pass': 'green',
    'unlikely': 'darkseagreen',
    'could go either way': 'slategrey',
    'likely': 'darkorange',
    'very_likely': 'royalblue',
    'will_pass': 'firebrick'
}

fig, axes = plt.subplots(2, 2, figsize=(14,10), sharex=True)
axes = axes.reshape(-1)
i = 0
for subset_name, bin_subset in bin_subsets.items():
    ax = axes[i]
    for bucket in bin_subset:
        msk = test_matrix['likelihood_bin'] == bucket
        sns.distplot(
            test_matrix[msk][feature_name], 
            hist=False,
            norm_hist=False, 
            kde=True,  
            label=bucket, 
            color=bin_color_map[bucket], 
            ax=ax,
#             bins=50
        )
    m = test_matrix[feature_name].max()
    ax.set_xlim(0, m)
#     ax.set_xlabel(display_name)
    sns.despine()
    
    i = i+1
    
    ax.legend() 


# ax.set_title('Distribution of {} w.r.t the likelihood bins'.format(feature_name))

# %% [markdown]
# #### Feature values by Buckets

# %%
temp = test_matrix.set_index(['entity_id', 'as_of_date'])
temp = temp.groupby('likelihood_bin').mean()
temp['sort_col'] = [4, 3,5, 2, 6, 1]
temp.sort_values('sort_col', inplace=True)

# %%
features_we_are_interested_in = [
    'event_counts_entity_id_all_important_sum',
    'event_counts_entity_id_all_action_count',
    'txt_entity_id_all_text_size_max',
#     'rec_evnts_entity_id_all_days_since_evnt_min',
#     'txt_entity_id_all_text_size_min',
#     'sponsors_entity_id_all_total_sponsors_max',
#     'event_counts_entity_id_2week_action_count',
#     'event_counts_entity_id_1month_action_count'
]

# %%
print(feature_importance['feature'].tolist())
# Out:
# ['event_counts_entity_id_all_DISTINCT chamber_count', 'event_counts_entity_id_all_action_count', 'txt_entity_id_all_text_size_min', 'sponsors_entity_id_all_total_sponsors_max', 'txt_entity_id_all_text_size_max', 'event_counts_entity_id_all_important_sum', 'event_counts_entity_id_1month_action_count', 'rec_evnts_entity_id_all_days_since_evnt_min', 'event_counts_entity_id_1month_DISTINCT chamber_count', 'txt_entity_id_1month_text_size_max', 'txt_entity_id_1month_text_size_min', 'rec_evnts_entity_id_all_days_since_imp_evnt_min', 'session_info_entity_id_all_remaining_time_min', 'sponsors_entity_id_all_dems_frac_max', 'event_counts_entity_id_2week_action_count', 'chamber_makeup_entity_id_all_hou_size_max', 'rec_txt_entity_id_all_days_since_last_version_min', 'sponsors_entity_id_all_reps_frac_max', 'txt_entity_id_2week_text_size_min', 'billinfo_entity_id_all_bill_age_max', 'txt_entity_id_2week_text_size_max', 'chamber_makeup_entity_id_all_sen_size_max', 'event_counts_entity_id_2week_DISTINCT chamber_count', 'chamber_makeup_entity_id_all_r_hou_ctrl_max', 'txt_entity_id_1week_text_size_max', 'session_info_entity_id_all_session_len_min', 'txt_entity_id_1week_text_size_min', 'event_counts_entity_id_1month_important_sum', 'chamber_makeup_entity_id_all_d_hou_ctrl_max', 'event_counts_entity_id_1week_action_count', 'txt_entity_id_all_doc_id_count', 'chamber_makeup_entity_id_all_d_sen_ctrl_max', 'chamber_makeup_entity_id_all_r_sen_ctrl_max', 'event_counts_entity_id_1week_DISTINCT chamber_count', 'billinfo_entity_id_all_bill_type_R_max', 'billinfo_entity_id_all_bill_type_B_max', 'event_counts_entity_id_2week_important_sum', 'event_counts_entity_id_1week_important_imp', 'event_counts_entity_id_2week_important_imp', 'billinfo_entity_id_all_state_CA_max', 'event_counts_entity_id_1week_important_sum', 'billinfo_entity_id_all_state_NY_max', 'chamber_makeup_entity_id_all_othr_hou_ctrl_max', 'rec_txt_entity_id_all_days_since_amendment_min', 'billinfo_entity_id_all_introduced_body_S_max', 'billinfo_entity_id_all_introduced_body_H_max', 'sponsors_entity_id_all_other_frac_max', 'txt_entity_id_1month_doc_id_count', 'chamber_makeup_entity_id_all_othr_sen_ctrl_max', 'event_counts_entity_id_1month_important_imp', 'txt_entity_id_all_num_amended_texts_sum', 'billinfo_entity_id_all_bill_type_JR_max', 'billinfo_entity_id_all_bill_type_CR_max', 'billinfo_entity_id_all_state_TN_max', 'txt_entity_id_2week_doc_id_count', 'txt_entity_id_1month_text_size_imp', 'billinfo_entity_id_all_state_HI_max', 'billinfo_entity_id_all_state_CO_max', 'billinfo_entity_id_all_introduced_body_A_max', 'txt_entity_id_2week_text_size_imp', 'billinfo_entity_id_all_state_RI_max', 'billinfo_entity_id_all_state_TX_max', 'rec_txt_entity_id_all_days_since_amendment_imp', 'billinfo_entity_id_all_state_MI_max', 'billinfo_entity_id_all_state_MO_max', 'txt_entity_id_1month_num_amended_texts_sum', 'txt_entity_id_1week_doc_id_count', 'billinfo_entity_id_all_state_IL_max', 'billinfo_entity_id_all_state_LA_max', 'billinfo_entity_id_all_state_NJ_max', 'txt_entity_id_1week_text_size_imp', 'txt_entity_id_2week_doc_id_imp', 'rec_txt_entity_id_all_days_since_last_versio_imp', 'txt_entity_id_all_text_size_imp', 'txt_entity_id_1month_doc_id_imp', 'billinfo_entity_id_all_state_MN_max', 'txt_entity_id_1week_doc_id_imp', 'billinfo_entity_id_all_state_NM_max', 'billinfo_entity_id_all_state_CT_max', 'txt_entity_id_all_doc_id_imp', 'billinfo_entity_id_all_state_MD_max', 'txt_entity_id_2week_num_amended_texts_sum', 'billinfo_entity_id_all_state_VA_max', 'billinfo_entity_id_all_state_AR_max', 'billinfo_entity_id_all_state_PA_max', 'billinfo_entity_id_all_state_MS_max', 'billinfo_entity_id_all_state_OK_max', 'billinfo_entity_id_all_state_NH_max', 'billinfo_entity_id_all_state_AZ_max', 'billinfo_entity_id_all_state_IN_max', 'billinfo_entity_id_all_state_MT_max', 'billinfo_entity_id_all_state_AL_max', 'billinfo_entity_id_all_state_KY_max', 'billinfo_entity_id_all_state_ND_max', 'billinfo_entity_id_all_state_OH_max',  ...

# %%
temp[features_we_are_interested_in].to_csv
# Out:
#                      event_counts_entity_id_all_important_sum  \
# likelihood_bin
# will_pass                                            7.831169
# very_likely                                          7.281928
# likely                                               9.176382
# could go either way                                  8.388043
# unlikely                                             2.546016
# will_not_pass                                        1.443547
#
#                      event_counts_entity_id_all_action_count  \
# likelihood_bin
# will_pass                                          24.012987
# very_likely                                        16.006066
# likely                                             15.378069
# could go either way                                14.388747
# unlikely                                            4.915465
# will_not_pass                                       2.436201
#
#                      txt_entity_id_all_text_size_max  \
# likelihood_bin
# will_pass                               45438.145022
# very_likely                             68128.335107
# likely                                  42936.226241
# could go either way                     47984.702261
# unlikely                                58656.142120
# will_not_pass                           39051.671316
#
#                      rec_evnts_entity_id_all_days_since_evnt_min  \
# likelihood_bin
# will_pass                                              15.380952
# very_likely                                            13.364943
# likely                                                 12.989047
# could go either way                                    25.900590
# unlikely                                               27.548913
# will_not_pass                                          34.742655
#
#                      txt_entity_id_all_text_size_min  \
# likelihood_bin
# will_pass                               16030.116883
# very_likely                             38075.165673
# likely                                  24965.583936
# could go either way                     25668.123214
# unlikely                                47606.974343
# will_not_pass                           35686.197487
#
#                      sponsors_entity_id_all_total_sponsors_max  \
# likelihood_bin
# will_pass                                             4.365801
# very_likely                                          14.771392
# likely                                                6.119099
# could go either way                                   7.014264
# unlikely                                              9.270866
# will_not_pass                                         5.089402
#
#                      event_counts_entity_id_2week_action_count  \
# likelihood_bin
# will_pass                                             3.779221
# very_likely                                           3.541507
# likely                                                1.964497
# could go either way                                   0.645417
# unlikely                                              0.486551
# will_not_pass                                         0.186831
#
#                      event_counts_entity_id_1month_action_count
# likelihood_bin
# will_pass                                              9.718615
# very_likely                                            4.903257
# likely                                                 2.987410
# could go either way                                    1.537026
# unlikely                                               1.048819
# will_not_pass                                          0.488038

# %%
t_list = features_we_are_interested_in + ['likelihood_bin']
sns.pairplot(data=test_matrix[t_list], hue='likelihood_bin')

# %% [markdown]
# ### Analysing each as_of_date

# %%
q = """
    select 
        to_char(as_of_date, 'YYYY-MM-DD') as as_of_date, count(*) as num_records, sum(label_value) as num_ones
    from test_results.predictions where model_id={}
    group by as_of_date
    order by as_of_date 
""".format(model_id)

as_of_date_stats = pd.read_sql(q, db_conn)

# %% [markdown]
# **Cohort size**

# %%
fig, ax = plt.subplots(figsize=(8,5))
df_t = as_of_date_stats[['as_of_date', 'num_records', 'num_ones']].melt('as_of_date', var_name='cohort',  value_name='value')
g = sns.barplot(data=df_t, x='as_of_date', y='value', hue='cohort')
t = g.set_xticklabels(labels=as_of_date_stats['as_of_date'], rotation=90)
sns.despine()

# %%
def precision_abs_asofdate(df, threshold=100):
    df = df.sort_values('score', ascending=False)
    
    num_ones = df['label_value'].iloc[:threshold].sum()
    
    d = dict()
    d['precision'] = float(num_ones/threshold)
    d['prevalance'] = float(df['label_value'].sum() / df.shape[0])
    
    return pd.Series(d)

threshold_abs = 100
t = model_predictions.groupby('as_of_date').apply(precision_abs_asofdate, threshold_abs).reset_index()

fig, ax = plt.subplots(figsize=(8,4))
g = sns.lineplot(data=t, x='as_of_date', y='precision', marker='o', label='precision')
sns.lineplot(data=t, x='as_of_date', y='prevalance', marker='o', label='prevalance')

t = g.set_xticklabels(labels=as_of_date_stats['as_of_date'], rotation=90)
ax.set_ylabel('Precision@{}_abs'.format(threshold_abs))
sns.despine()

# %% [markdown]
# #### Comparing lists
#
# We consider each bucket as a list and compare overlap within that

# %%
q = """
    with models_in_460 as (
        select 
            model_id, train_end_time
        from triage_metadata.experiment_models join triage_metadata.models using(model_hash)
        where experiment_hash='f08d1c3b0dc1e385cc88f59a28c44b30'
        order by train_end_time
    ),
    models_in_375 as (
        select 
            model_id, train_end_time 
        from triage_metadata.experiment_models join triage_metadata.models using(model_hash)
        where experiment_hash='aa36a41222408534233ebd20b7adca54'
        order by train_end_time
    )
    select
        a.model_id as model_460,
        b.model_id as model_375,
        train_end_time
    from models_in_460 a join models_in_375 b using(train_end_time)
"""

model_ids_in_two_groups = pd.read_sql(q, db_conn)
model_ids_in_two_groups
# Out:
#     model_460  model_375 train_end_time
# 0       11759      11772     2012-07-01
# 1       11760      11773     2013-01-01
# 2       11761      11774     2013-07-01
# 3       11762      11775     2014-01-01
# 4       11763      11776     2014-07-01
# 5       11764      11777     2015-01-01
# 6       11765      11778     2015-07-01
# 7       11766      11779     2016-01-01
# 8       11767      11780     2016-07-01
# 9       11768      11781     2017-01-01
# 10      11769      11782     2017-07-01
# 11      11770      11783     2018-01-01
# 12      11771      11784     2018-07-01

# %%
union_q = """
    select distinct entity_id from test_results.predictions 
    where model_id={model_id_g1} and score >= {thresh_lower} and score < {thresh_upper}
	UNION
	select distinct entity_id from test_results.predictions 
    where model_id={model_id_g2} and score >= {thresh_lower} and score < {thresh_upper}
"""

intersection_q = """
    select distinct entity_id from test_results.predictions 
    where model_id={model_id_g1} and score >= {thresh_lower} and score < {thresh_upper}
	INTERSECT
	select distinct entity_id from test_results.predictions 
    where model_id={model_id_g2} and score >= {thresh_lower} and score < {thresh_upper}
"""

# %%
def calc_iou(row, likelihood_bins):
    for bin_name, lims in likelihood_bins.items(): 
        q = union_q.format(
            model_id_g1=row['model_375'],
            model_id_g2=row['model_460'],
            thresh_lower=lims[0],
            thresh_upper=lims[1]
        )
        un = pd.read_sql(q, db_conn)

        q = intersection_q.format(
            model_id_g1=row['model_375'],
            model_id_g2=row['model_460'],
            thresh_lower=lims[0],
            thresh_upper=lims[1]
        )
        inter = pd.read_sql(q, db_conn)

        if len(un) == 0:
            row['iou_{}'.format(bin_name)] = None
        else:
            row['iou_{}'.format(bin_name)] = len(inter) / len(un) 
    
    return row

# %%
ious = model_ids_in_two_groups.apply(calc_iou, likelihood_bins=buckets, axis=1)

# %%
ious
# Out:
#     model_460  model_375 train_end_time  iou_will_not_pass  iou_unlikely  \
# 0       11759      11772     2012-07-01           0.936414      0.972514
# 1       11760      11773     2013-01-01           0.951475      0.972427
# 2       11761      11774     2013-07-01           0.938177      0.954325
# 3       11762      11775     2014-01-01           0.954313      0.962148
# 4       11763      11776     2014-07-01           0.943051      0.911164
# 5       11764      11777     2015-01-01           0.962465      0.944070
# 6       11765      11778     2015-07-01           0.950289      0.938125
# 7       11766      11779     2016-01-01           0.964084      0.970471
# 8       11767      11780     2016-07-01           0.955081      0.914751
# 9       11768      11781     2017-01-01           0.959984      0.957962
# 10      11769      11782     2017-07-01           0.914021      0.948822
# 11      11770      11783     2018-01-01           0.919152      0.967021
# 12      11771      11784     2018-07-01           0.936534      0.889872
#
#     iou_could go either way  iou_likely  iou_very_likely  iou_will_pass
# 0                  0.963706    0.939138         0.904215            NaN
# 1                  0.936297    0.932980         0.894998       0.900498
# 2                  0.888942    0.903150         0.947368       0.581818
# 3                  0.921813    0.933559         0.899676       0.806993
# 4                  0.949574    0.947865         0.935449       0.970588
# 5                  0.935129    0.929005         0.945001       0.877003
# 6                  0.918422    0.949904         0.932363       0.875000
# 7                  0.926503    0.919092         0.942186       0.853199
# 8                  0.952148    0.954724         0.939590       0.889362
# 9                  0.917915    0.914392         0.934554       0.717210
# 10                 0.896193    0.949882         0.942537       0.824561
# 11                 0.922612    0.924536         0.929006       0.842447
# 12                 0.951907    0.941378         0.928062       0.876833

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=ious, x='train_end_time', y='iou_will_pass', marker='o', label='will_pass')
sns.lineplot(data=ious, x='train_end_time', y='iou_will_not_pass', marker='o', label='will_not_pass')
sns.lineplot(data=ious, x='train_end_time', y='iou_unlikely', marker='o', label='unlikely')
sns.lineplot(data=ious, x='train_end_time', y='iou_likely', marker='o', label='likely')
sns.lineplot(data=ious, x='train_end_time', y='iou_very_likely', marker='o', label='very_likely')
sns.lineplot(data=ious, x='train_end_time', y='iou_could go either way', marker='o', label='could go either way')
sns.despine()
plt.legend(bbox_to_anchor=(1.05, 1))
ax.set_ylabel('iou values')
# Out:
# Text(0, 0.5, 'iou values')
