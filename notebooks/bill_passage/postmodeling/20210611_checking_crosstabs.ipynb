# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from src.utils.general import get_db_conn, get_boto3_session, load_model_s3, load_matrix_s3
from src.utils import project_constants as constants

# %%
cred_file = '../conf/local/credentials.yaml'
db_conn=get_db_conn(cred_file)
s3_session = get_boto3_session(cred_file)

# %% [markdown]
# #### mean ratios between bins

# %%
q = """
    select distinct related_likelihood_bins 
    from test_results.crosstabs_bins_3month
"""
bin_combos = pd.read_sql(q, db_conn)

# %%
q = """select *
    from test_results.crosstabs_bins_3month
    where metric='mean_ratio' and
    model_id = 16465
"""

mean_ratios = pd.read_sql(q, db_conn)

# %% [markdown]
# #### Will pass vs Will not pass

# %%
def get_top_k_mean_ratio(bin_labels, k=20):
    msk = mean_ratios['related_likelihood_bins'] == bin_labels
    df = mean_ratios[msk].sort_values('value', ascending=False)
    df.replace([np.inf, -np.inf], np.nan, inplace=True)
    
    m2 = df['value'].isna()
    m3 = df['feature_name'].str.contains('_state_')
    m4 = df['feature_name'].str.contains('_bill_type_')
    return df[~m2 & ~m3 & ~m4][:k]

# %%
get_top_k_mean_ratio('will_pass, will_not_pass', 20)
# Out:
#        model_id as_of_date      metric   related_likelihood_bins  \
# 2972      16465 2018-03-08  mean_ratio  will_pass, will_not_pass
# 10112     16465 2018-03-29  mean_ratio  will_pass, will_not_pass
# 7772      16465 2018-03-22  mean_ratio  will_pass, will_not_pass
# 752       16465 2018-03-01  mean_ratio  will_pass, will_not_pass
# 3092      16465 2018-03-08  mean_ratio  will_pass, will_not_pass
# 3098      16465 2018-03-08  mean_ratio  will_pass, will_not_pass
# 5432      16465 2018-03-15  mean_ratio  will_pass, will_not_pass
# 7778      16465 2018-03-22  mean_ratio  will_pass, will_not_pass
# 10118     16465 2018-03-29  mean_ratio  will_pass, will_not_pass
# 10110     16465 2018-03-29  mean_ratio  will_pass, will_not_pass
# 5438      16465 2018-03-15  mean_ratio  will_pass, will_not_pass
# 7770      16465 2018-03-22  mean_ratio  will_pass, will_not_pass
# 750       16465 2018-03-01  mean_ratio  will_pass, will_not_pass
# 10114     16465 2018-03-29  mean_ratio  will_pass, will_not_pass
# 758       16465 2018-03-01  mean_ratio  will_pass, will_not_pass
# 754       16465 2018-03-01  mean_ratio  will_pass, will_not_pass
# 3090      16465 2018-03-08  mean_ratio  will_pass, will_not_pass
# 7774      16465 2018-03-22  mean_ratio  will_pass, will_not_pass
# 3086      16465 2018-03-08  mean_ratio  will_pass, will_not_pass
# 5430      16465 2018-03-15  mean_ratio  will_pass, will_not_pass
#
#                                           feature_name       value
# 2972          bl_sp_entity_id_all_sponsors_frac_lc_max  177.100775
# 10112            evnt_cts_entity_id_1week_action_count   63.193472
# 7772             evnt_cts_entity_id_1week_action_count   60.103179
# 752              evnt_cts_entity_id_1week_action_count   49.252660
# 3092             evnt_cts_entity_id_1week_action_count   46.774227
# 3098             evnt_cts_entity_id_2week_action_count   37.318289
# 5432             evnt_cts_entity_id_1week_action_count   36.637289
# 7778             evnt_cts_entity_id_2week_action_count   36.445406
# 10118            evnt_cts_entity_id_2week_action_count   36.110555
# 10110  evnt_cts_entity_id_1week_DISTINCT chamber_count   29.903038
# 5438             evnt_cts_entity_id_2week_action_count   26.024434
# 7770   evnt_cts_entity_id_1week_DISTINCT chamber_count   25.937062
# 750    evnt_cts_entity_id_1week_DISTINCT chamber_count   25.096096
# 10114           evnt_cts_entity_id_1week_important_sum   24.396426
# 758              evnt_cts_entity_id_2week_action_count   23.644392
# 754             evnt_cts_entity_id_1week_important_sum   23.160134
# 3090   evnt_cts_entity_id_1week_DISTINCT chamber_count   22.835344
# 7774            evnt_cts_entity_id_1week_important_sum   18.762522
# 3086            evnt_cts_entity_id_1month_action_count   18.633933
# 5430   evnt_cts_entity_id_1week_DISTINCT chamber_count   18.609404

# %% [markdown]
# #### Very likely vs Will_not_pass

# %%
get_top_k_mean_ratio('very_likely, will_not_pass', 20)
# Out:
#       model_id as_of_date      metric     related_likelihood_bins  \
# 476      16465 2018-03-01  mean_ratio  very_likely, will_not_pass
# 9836     16465 2018-03-29  mean_ratio  very_likely, will_not_pass
# 2816     16465 2018-03-08  mean_ratio  very_likely, will_not_pass
# 5156     16465 2018-03-15  mean_ratio  very_likely, will_not_pass
# 9843     16465 2018-03-29  mean_ratio  very_likely, will_not_pass
# 9829     16465 2018-03-29  mean_ratio  very_likely, will_not_pass
# 9833     16465 2018-03-29  mean_ratio  very_likely, will_not_pass
# 9841     16465 2018-03-29  mean_ratio  very_likely, will_not_pass
# 9835     16465 2018-03-29  mean_ratio  very_likely, will_not_pass
# 596      16465 2018-03-01  mean_ratio  very_likely, will_not_pass
# 2936     16465 2018-03-08  mean_ratio  very_likely, will_not_pass
# 7616     16465 2018-03-22  mean_ratio  very_likely, will_not_pass
# 2942     16465 2018-03-08  mean_ratio  very_likely, will_not_pass
# 9956     16465 2018-03-29  mean_ratio  very_likely, will_not_pass
# 602      16465 2018-03-01  mean_ratio  very_likely, will_not_pass
# 9962     16465 2018-03-29  mean_ratio  very_likely, will_not_pass
# 594      16465 2018-03-01  mean_ratio  very_likely, will_not_pass
# 9838     16465 2018-03-29  mean_ratio  very_likely, will_not_pass
# 7622     16465 2018-03-22  mean_ratio  very_likely, will_not_pass
# 598      16465 2018-03-01  mean_ratio  very_likely, will_not_pass
#
#                                          feature_name       value
# 476          bl_sp_entity_id_all_sponsors_frac_lc_max  546.763712
# 9836         bl_sp_entity_id_all_sponsors_frac_lc_max  248.849456
# 2816         bl_sp_entity_id_all_sponsors_frac_lc_max  127.888043
# 5156         bl_sp_entity_id_all_sponsors_frac_lc_max  103.547477
# 9843        bl_sp_entity_id_all_uc_ctrl_prty_frac_imp   61.120919
# 9829                bl_sp_entity_id_all_dems_frac_imp   61.120919
# 9833               bl_sp_entity_id_all_other_frac_imp   61.120919
# 9841           bl_sp_entity_id_all_total_sponsors_imp   61.120919
# 9835                bl_sp_entity_id_all_reps_frac_imp   61.120919
# 596             evnt_cts_entity_id_1week_action_count   47.699100
# 2936            evnt_cts_entity_id_1week_action_count   38.033344
# 7616            evnt_cts_entity_id_1week_action_count   35.298616
# 2942            evnt_cts_entity_id_2week_action_count   33.162584
# 9956            evnt_cts_entity_id_1week_action_count   32.735204
# 602             evnt_cts_entity_id_2week_action_count   26.529100
# 9962            evnt_cts_entity_id_2week_action_count   25.836295
# 594   evnt_cts_entity_id_1week_DISTINCT chamber_count   23.551878
# 9838         bl_sp_entity_id_all_sponsors_frac_uc_max   23.064498
# 7622            evnt_cts_entity_id_2week_action_count   22.964595
# 598            evnt_cts_entity_id_1week_important_sum   21.647794

# %% [markdown]
# #### Very likey vs unlikely

# %%
get_top_k_mean_ratio('will_pass, unlikely', 20)
# Out:
#        model_id as_of_date      metric related_likelihood_bins  \
# 8396      16465 2018-03-22  mean_ratio     will_pass, unlikely
# 10736     16465 2018-03-29  mean_ratio     will_pass, unlikely
# 3596      16465 2018-03-08  mean_ratio     will_pass, unlikely
# 3716      16465 2018-03-08  mean_ratio     will_pass, unlikely
# 6056      16465 2018-03-15  mean_ratio     will_pass, unlikely
# 8402      16465 2018-03-22  mean_ratio     will_pass, unlikely
# 10734     16465 2018-03-29  mean_ratio     will_pass, unlikely
# 3722      16465 2018-03-08  mean_ratio     will_pass, unlikely
# 8398      16465 2018-03-22  mean_ratio     will_pass, unlikely
# 10742     16465 2018-03-29  mean_ratio     will_pass, unlikely
# 1376      16465 2018-03-01  mean_ratio     will_pass, unlikely
# 8394      16465 2018-03-22  mean_ratio     will_pass, unlikely
# 6062      16465 2018-03-15  mean_ratio     will_pass, unlikely
# 1378      16465 2018-03-01  mean_ratio     will_pass, unlikely
# 3714      16465 2018-03-08  mean_ratio     will_pass, unlikely
# 10738     16465 2018-03-29  mean_ratio     will_pass, unlikely
# 3710      16465 2018-03-08  mean_ratio     will_pass, unlikely
# 6054      16465 2018-03-15  mean_ratio     will_pass, unlikely
# 1382      16465 2018-03-01  mean_ratio     will_pass, unlikely
# 3724      16465 2018-03-08  mean_ratio     will_pass, unlikely
#
#                                           feature_name      value
# 8396             evnt_cts_entity_id_1week_action_count  18.932924
# 10736            evnt_cts_entity_id_1week_action_count  15.432126
# 3596          bl_sp_entity_id_all_sponsors_frac_lc_max  14.114618
# 3716             evnt_cts_entity_id_1week_action_count  12.943459
# 6056             evnt_cts_entity_id_1week_action_count  11.430082
# 8402             evnt_cts_entity_id_2week_action_count  11.145663
# 10734  evnt_cts_entity_id_1week_DISTINCT chamber_count  10.894903
# 3722             evnt_cts_entity_id_2week_action_count  10.703648
# 8398            evnt_cts_entity_id_1week_important_sum  10.362152
# 10742            evnt_cts_entity_id_2week_action_count  10.044503
# 1376             evnt_cts_entity_id_1week_action_count   9.897163
# 8394   evnt_cts_entity_id_1week_DISTINCT chamber_count   9.448981
# 6062             evnt_cts_entity_id_2week_action_count   9.062449
# 1378            evnt_cts_entity_id_1week_important_sum   8.503044
# 3714   evnt_cts_entity_id_1week_DISTINCT chamber_count   7.625598
# 10738           evnt_cts_entity_id_1week_important_sum   7.599084
# 3710            evnt_cts_entity_id_1month_action_count   7.434657
# 6054   evnt_cts_entity_id_1week_DISTINCT chamber_count   7.136729
# 1382             evnt_cts_entity_id_2week_action_count   6.449429
# 3724            evnt_cts_entity_id_2week_important_sum   6.416063
